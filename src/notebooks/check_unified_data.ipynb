# %%
# check if dupes
df.duplicated(subset=['news_id']).sum()

# %%
# check if missing values
df.isna().sum()

# %%
df.label.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.label.value_counts()
#
# NameError: name 'df' is not defined

# %%
df.source.value_counts()

# %%
df.info()

# %%
df.describe(include='all')

# %%
import pandas as pd

# check stacked datasets to see if produced correctly (need to fix path)
df = load_all_news()
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
#       2 from pathlib import Path
# ----> 3 from preprocess import parse_news
#       5 # check stacked datasets to see if produced correctly
#       6 df = load_all_news()
#
# ModuleNotFoundError: No module named 'preprocess'
